# %% [markdown]
# # Project 3 - Boston Crime
# ### By Charlotte Burbridge
# ---

# %%
import pandas as pd
import pandas_profiling
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
crimes = pd.read_csv('crime.csv', parse_dates = ['OCCURRED_ON_DATE'])
crimes.dtypes
# Out:
# INCIDENT_NUMBER                object
# OFFENSE_CODE                    int64
# OFFENSE_CODE_GROUP             object
# OFFENSE_DESCRIPTION            object
# DISTRICT                       object
# REPORTING_AREA                float64
# SHOOTING                       object
# OCCURRED_ON_DATE       datetime64[ns]
# YEAR                            int64
# MONTH                           int64
# DAY_OF_WEEK                    object
# HOUR                            int64
# UCR_PART                       object
# STREET                         object
# Lat                           float64
# Long                          float64
# Location                       object
# dtype: object

# %%
#profile = crimes.profile_report(title='Boston Crimes Profiling')
#profile.to_file(output_file='boston-crimes-profiling.html')

# %%
crimes['SHOOTING'] = crimes['SHOOTING'].fillna(0)
crimes
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP  \
# 0           I182070945           619               Larceny
# 1           I182070943          1402             Vandalism
# 2           I182070941          3410                 Towed
# 3           I182070940          3114  Investigate Property
# 4           I182070938          3114  Investigate Property
# ...                ...           ...                   ...
# 319068   I050310906-00          3125       Warrant Arrests
# 319069   I030217815-08           111              Homicide
# 319070   I030217815-08          3125       Warrant Arrests
# 319071   I010370257-00          3125       Warrant Arrests
# 319072       142052550          3125       Warrant Arrests
#
#                         OFFENSE_DESCRIPTION DISTRICT  REPORTING_AREA SHOOTING  \
# 0                        LARCENY ALL OTHERS      D14           808.0        0
# 1                                 VANDALISM      C11           347.0        0
# 2                       TOWED MOTOR VEHICLE       D4           151.0        0
# 3                      INVESTIGATE PROPERTY       D4           272.0        0
# 4                      INVESTIGATE PROPERTY       B3           421.0        0
# ...                                     ...      ...             ...      ...
# 319068                       WARRANT ARREST       D4           285.0        0
# 319069  MURDER, NON-NEGLIGIENT MANSLAUGHTER      E18           520.0        0
# 319070                       WARRANT ARREST      E18           520.0        0
# 319071                       WARRANT ARREST      E13           569.0        0
# 319072                       WARRANT ARREST       D4           903.0        0
#
#           OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR    UCR_PART  \
# 0      2018-09-02 13:00:00  2018      9      Sunday    13    Part One
# 1      2018-08-21 00:00:00  2018      8     Tuesday     0    Part Two
# 2      2018-09-03 19:27:00  2018      9      Monday    19  Part Three
# 3      2018-09-03 21:16:00  2018      9      Monday    21  Part Three
# 4      2018-09-03 21:05:00  2018      9      Monday    21  Part Three
# ...                    ...   ...    ...         ...   ...         ...
# 319068 2016-06-05 17:25:00  2016      6      Sunday    17  Part Three
# 319069 2015-07-09 13:38:00  2015      7    Thursday    13    Part One
# 319070 2015-07-09 13:38:00  2015      7    Thursday    13  Part Three
# 319071 2016-05-31 19:35:00  2016      5     Tuesday    19  Part Three
# 319072 2015-06-22 00:12:00  2015      6      Monday     0  Part Three
#
#                    STREET        Lat       Long                     Location
# 0              LINCOLN ST  42.357791 -71.139371  (42.35779134, -71.13937053)
# 1                HECLA ST  42.306821 -71.060300  (42.30682138, -71.06030035)
# 2             CAZENOVE ST  42.346589 -71.072429  (42.34658879, -71.07242943)
# 3              NEWCOMB ST  42.334182 -71.078664  (42.33418175, -71.07866441)
# 4                DELHI ST  42.275365 -71.090361  (42.27536542, -71.09036101)
# ...                   ...        ...        ...                          ...
# 319068        COVENTRY ST  42.336951 -71.085748  (42.33695098, -71.08574813)
# 319069           RIVER ST  42.255926 -71.123172  (42.25592648, -71.12317207)
# 319070           RIVER ST  42.255926 -71.123172  (42.25592648, -71.12317207)
# 319071  NEW WASHINGTON ST  42.302333 -71.111565  (42.30233307, -71.11156487)
# 319072      WASHINGTON ST  42.333839 -71.080290  (42.33383935, -71.08029038)
#
# [319073 rows x 17 columns]

# %%
crimes['SHOOTING'] = crimes['SHOOTING'].astype('bool')
crimes
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE    OFFENSE_CODE_GROUP  \
# 0           I182070945           619               Larceny
# 1           I182070943          1402             Vandalism
# 2           I182070941          3410                 Towed
# 3           I182070940          3114  Investigate Property
# 4           I182070938          3114  Investigate Property
# ...                ...           ...                   ...
# 319068   I050310906-00          3125       Warrant Arrests
# 319069   I030217815-08           111              Homicide
# 319070   I030217815-08          3125       Warrant Arrests
# 319071   I010370257-00          3125       Warrant Arrests
# 319072       142052550          3125       Warrant Arrests
#
#                         OFFENSE_DESCRIPTION DISTRICT  REPORTING_AREA  \
# 0                        LARCENY ALL OTHERS      D14           808.0
# 1                                 VANDALISM      C11           347.0
# 2                       TOWED MOTOR VEHICLE       D4           151.0
# 3                      INVESTIGATE PROPERTY       D4           272.0
# 4                      INVESTIGATE PROPERTY       B3           421.0
# ...                                     ...      ...             ...
# 319068                       WARRANT ARREST       D4           285.0
# 319069  MURDER, NON-NEGLIGIENT MANSLAUGHTER      E18           520.0
# 319070                       WARRANT ARREST      E18           520.0
# 319071                       WARRANT ARREST      E13           569.0
# 319072                       WARRANT ARREST       D4           903.0
#
#         SHOOTING    OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  \
# 0          False 2018-09-02 13:00:00  2018      9      Sunday    13
# 1          False 2018-08-21 00:00:00  2018      8     Tuesday     0
# 2          False 2018-09-03 19:27:00  2018      9      Monday    19
# 3          False 2018-09-03 21:16:00  2018      9      Monday    21
# 4          False 2018-09-03 21:05:00  2018      9      Monday    21
# ...          ...                 ...   ...    ...         ...   ...
# 319068     False 2016-06-05 17:25:00  2016      6      Sunday    17
# 319069     False 2015-07-09 13:38:00  2015      7    Thursday    13
# 319070     False 2015-07-09 13:38:00  2015      7    Thursday    13
# 319071     False 2016-05-31 19:35:00  2016      5     Tuesday    19
# 319072     False 2015-06-22 00:12:00  2015      6      Monday     0
#
#           UCR_PART             STREET        Lat       Long  \
# 0         Part One         LINCOLN ST  42.357791 -71.139371
# 1         Part Two           HECLA ST  42.306821 -71.060300
# 2       Part Three        CAZENOVE ST  42.346589 -71.072429
# 3       Part Three         NEWCOMB ST  42.334182 -71.078664
# 4       Part Three           DELHI ST  42.275365 -71.090361
# ...            ...                ...        ...        ...
# 319068  Part Three        COVENTRY ST  42.336951 -71.085748
# 319069    Part One           RIVER ST  42.255926 -71.123172
# 319070  Part Three           RIVER ST  42.255926 -71.123172
# 319071  Part Three  NEW WASHINGTON ST  42.302333 -71.111565
# 319072  Part Three      WASHINGTON ST  42.333839 -71.080290
#
#                            Location
# 0       (42.35779134, -71.13937053)
# 1       (42.30682138, -71.06030035)
# 2       (42.34658879, -71.07242943)
# 3       (42.33418175, -71.07866441)
# 4       (42.27536542, -71.09036101)
# ...                             ...
# 319068  (42.33695098, -71.08574813)
# 319069  (42.25592648, -71.12317207)
# 319070  (42.25592648, -71.12317207)
# 319071  (42.30233307, -71.11156487)
# 319072  (42.33383935, -71.08029038)
#
# [319073 rows x 17 columns]

# %% [markdown]
# ### Because I can't see any trues in my shooting column, I'm going to use value_counts() to check if they are all false or if there are trues as well.

# %%
crimes['SHOOTING'].value_counts()
# Out:
# False    318054
# True       1019
# Name: SHOOTING, dtype: int64

# %% [markdown]
# #### Answer these basic questions, using code to investigate (as much as possible):
# What is the range of dates being reported?
# What are all the unique groups of offense codes and which are most prevalent in the data?
#
# #### Answer these questions (and produce appropriate accompanying visualizations):
# What percentage of murders involved a shooting?
# Look at Murder, non-negligent manslaughter (offense_code 111)
# Also note that seaborn has no pie chart! If that's what you want, you need to use matplotlib.
# Are there certain times of the year when crime is more prevalent in Boston?
# If you want to count crimes on each day, you will need to create a new 'date' column by extracting the date from the datetime.
# Answer two (or more) unique questions of your own, again using visualizations.

# %% [markdown]
# ## What is the range of dates being reported?

# %%
date_range = str(crimes['OCCURRED_ON_DATE'].dt.date.min()) + ' to ' +str(crimes['OCCURRED_ON_DATE'].dt.date.max())
date_range

# thank you stackoverflow for making this easy for me
# https://stackoverflow.com/questions/65349787/how-to-find-the-range-of-dates-from-a-datetime-column-in-a-dataframe
# Out:
# '2015-06-15 to 2018-09-03'

# %% [markdown]
# ## What are the unique groups of offense codes and which are most prevalent in the data?

# %%
crimes['OFFENSE_CODE_GROUP'].value_counts()
# Out:
# Motor Vehicle Accident Response              37132
# Larceny                                      25935
# Medical Assistance                           23540
# Investigate Person                           18750
# Other                                        18075
#                                              ...
# HUMAN TRAFFICKING                                7
# INVESTIGATE PERSON                               4
# Biological Threat                                2
# HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE        2
# Burglary - No Property Taken                     2
# Name: OFFENSE_CODE_GROUP, Length: 67, dtype: int64

# %% [markdown]
# ## What percentage of murders involved a shooting?
#
# ### First I'm going to make a new dataframe just for crimes with Murder, Non-Negligient Manslaughter

# %%
murderdf = crimes.loc[crimes['OFFENSE_CODE'] == 111]
murderdf
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP  \
# 3259        I182067317           111           Homicide
# 5689        I182064699           111           Homicide
# 6278        I182064056           111           Homicide
# 10813       I182059055           111           Homicide
# 11021       I182058835           111           Homicide
# ...                ...           ...                ...
# 312521      I152056746           111           Homicide
# 312945      I152056250           111           Homicide
# 313764      I152055311           111           Homicide
# 314239      I152054787           111           Homicide
# 319069   I030217815-08           111           Homicide
#
#                         OFFENSE_DESCRIPTION DISTRICT  REPORTING_AREA  \
# 3259    MURDER, NON-NEGLIGIENT MANSLAUGHTER       B2           312.0
# 5689    MURDER, NON-NEGLIGIENT MANSLAUGHTER       B3           466.0
# 6278    MURDER, NON-NEGLIGIENT MANSLAUGHTER       B3           410.0
# 10813   MURDER, NON-NEGLIGIENT MANSLAUGHTER       B3           908.0
# 11021   MURDER, NON-NEGLIGIENT MANSLAUGHTER       B3           435.0
# ...                                     ...      ...             ...
# 312521  MURDER, NON-NEGLIGIENT MANSLAUGHTER      E13           639.0
# 312945  MURDER, NON-NEGLIGIENT MANSLAUGHTER       A1           112.0
# 313764  MURDER, NON-NEGLIGIENT MANSLAUGHTER       B2           322.0
# 314239  MURDER, NON-NEGLIGIENT MANSLAUGHTER       B2           281.0
# 319069  MURDER, NON-NEGLIGIENT MANSLAUGHTER      E18           520.0
#
#         SHOOTING    OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  UCR_PART  \
# 3259        True 2018-08-22 15:00:00  2018      8   Wednesday    15  Part One
# 5689        True 2018-08-14 09:30:00  2018      8     Tuesday     9  Part One
# 6278        True 2018-08-11 23:14:00  2018      8    Saturday    23  Part One
# 10813      False 2018-07-26 18:14:00  2018      7    Thursday    18  Part One
# 11021       True 2018-07-25 22:57:00  2018      7   Wednesday    22  Part One
# ...          ...                 ...   ...    ...         ...   ...       ...
# 312521     False 2015-07-02 16:30:00  2015      7    Thursday    16  Part One
# 312945     False 2015-07-08 12:15:00  2015      7   Wednesday    12  Part One
# 313764      True 2015-07-04 22:47:00  2015      7    Saturday    22  Part One
# 314239      True 2015-07-02 23:08:00  2015      7    Thursday    23  Part One
# 319069     False 2015-07-09 13:38:00  2015      7    Thursday    13  Part One
#
#                STREET        Lat       Long                     Location
# 3259     HOLLANDER ST  42.315689 -71.089514  (42.31568920, -71.08951391)
# 5689       DEERING RD  42.284140 -71.093051  (42.28414025, -71.09305138)
# 6278    MANCHESTER ST  42.274040 -71.076301  (42.27404039, -71.07630093)
# 10813      SHANDON RD  42.295054 -71.089041  (42.29505434, -71.08904077)
# 11021      NORFOLK ST  42.288048 -71.077667  (42.28804798, -71.07766654)
# ...               ...        ...        ...                          ...
# 312521  ROBINWOOD AVE  42.316240 -71.112670  (42.31624019, -71.11267011)
# 312945     CHAUNCY ST  42.352517 -71.061129  (42.35251737, -71.06112927)
# 313764   GLENBURNE ST  42.315122 -71.082520  (42.31512218, -71.08252020)
# 314239  GREENVILLE ST  42.326968 -71.080519  (42.32696802, -71.08051941)
# 319069       RIVER ST  42.255926 -71.123172  (42.25592648, -71.12317207)
#
# [161 rows x 17 columns]

# %% [markdown]
# ### And now stackoverflow helps me find the percentage of murders with shootings (True) and murders without shootings (False)
#
# ##### https://stackoverflow.com/questions/52229909/panda-python-calculating-what-percentage-of-values-are-true-and-false-out-of-t

# %%
murderdf['SHOOTING'].value_counts(normalize=True).mul(100).astype(str)+'%'
# Out:
# True     75.15527950310559%
# False    24.84472049689441%
# Name: SHOOTING, dtype: object

# %% [markdown]
# ### 75.15527950310559% of murders in this dataframe involved a shooting.

# %%
import matplotlib.pyplot as plt
labels = 'Murders with a Shooting', 'Murders without a Shooting'
sizes = [75.15527950310559, 24.84472049689441]
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')
plt.show()

# thank you to matplotlib for teaching me how to use their syntax 
# https://matplotlib.org/stable/gallery/pie_and_polar_charts/pie_features.html

# %% [markdown]
# ## Are there certain times of the year when crime is more prevalent in Boston?

# %%
# If you want to count crimes on each day, 
# you will need to create a new 'date' column by extracting the date from the datetime.
