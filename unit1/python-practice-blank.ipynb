# %% [markdown]
# # Python Practice
# ---
#
# ## Boptalk
#
# Boptalk is a secret language allowing those who know it to communicate in unreasonably long and silly sentences. For instance, if I wanted to say "hello" in Boptalk, I would say "hop e lop lop o".
#
# The logic is this: for each letter in the sentence you want to speak, if that letter is a vowel you simply say it, otherwise you add "op" to it.
#
# In the cell below, use the .input() function to get input from the user. (Look it up if you don't know how.)
#
# Then, taking that input, create and display the Boptalk output. For this problem, you can use strings alone.

# %%
phrase = input("What do you want to be said in Boptalk? ")
vowels = ['a', 'e', 'i', 'o', 'u']
bopTalk = ' '

for letter in phrase:
    if letter in vowels:
        bopTalk = bopTalk + letter
    else:
        bopTalk = bopTalk + letter + 'op'
        
bopTalk
# Out:
# What do you want to be said in Boptalk? hello
# ' hopeloplopo'

# %% [markdown]
# ## One-line Boptalk 🌶️
#
# Now, can you use list comprehension to do it in one line (except the vowels declaration and input)?
#
# You will need to convert the list into a string with spaces inserted. Google how to do this.

# %%
phrase = input("What do you want to be said in Boptalk? ")
vowels = ['a', 'e', 'i', 'o', 'u']
boptalk = ' '

#i thought that this would work but I think the order is the problem.
#i don't know why i put the "boptalk ==" things in brackets but it seemed to help the error?
# i fdont know how to get it to add the -op part, it just prints the numbers seperately


[[boptalk == bobtalk + letter] if letter in vowels [boptalk == boptalk + letter + "op"] else letter for letter in phrase]
# Out:
# What do you want to be said in Boptalk? hello
# ['h', 'e', 'l', 'l', 'o']

# %% [markdown]
# ## Dictionaries 🌶️🌶️
#
# There is a Python file that you should have in the same directory as this Notebook, called book.py. It is a simple Python script that contains one very long list of lowercase words. You can use that list in this Notebook by importing it like so:
#
# ```python
# from book import words
# ```
#
# You will then have a list stored in the variable "words". Go ahead and import the data and output it to verify. (It is so long that you won't see all 58,110 words.)

# %%
from book import words
words
# Out:
# ['despising',
#  'morbidity',
#  'assimilated',
#  'monostable',
#  'anodyne',
#  'alights',
#  'misdirecting',
#  'notify',
#  'licentious',
#  'lighthearted',
#  'triennial',
#  'polisher',
#  'blurring',
#  'merriest',
#  'girders',
#  'pagination',
#  'speedwell',
#  'range',
#  'entrusted',
#  'notation',
#  'volleyball',
#  'dwindle',
#  'sardines',
#  'corporatist',
#  'definitional',
#  'bovine',
#  'prohibitively',
#  'electro',
#  'smartest',
#  'frivolously',
#  'novelists',
#  'communicates',
#  'voyages',
#  'shatteringly',
#  'smallness',
#  'honeymooners',
#  'windings',
#  'enchantment',
#  'bedside',
#  'december',
#  'resistances',
#  'harp',
#  'kraal',
#  'wriggling',
#  'coauthor',
#  'editions',
#  'triteness',
#  'vamp',
#  'vamps',
#  'strained',
#  'stalactite',
#  'isomers',
#  'hilarious',
#  'acuter',
#  'gearbox',
#  'renew',
#  'coordinators',
#  'toys',
#  'swirling',
#  'dunked',
#  'inextinguishable',
#  'cry',
#  'considerate',
#  'girlfriends',
#  'sisters',
#  'race',
#  'vacuoles',
#  'amplified',
#  'stewardship',
#  'magnitude',
#  'visionaries',
#  'rescheduling',
#  'interpreter',
#  'neglect',
#  'reticulated',
#  'crowbar',
#  'handpicked',
#  'excitements',
#  'heavyweights',
#  'wonderingly',
#  'bibles',
#  'swayed',
#  'flexor',
#  'payloads',
#  'despondent',
#  'compositor',
#  'overindulgence',
#  'banks',
#  'indefinably',
#  'compatriots',
#  'bylaw',
#  'counterfeits',
#  'trombonist',
#  'encyclopaedic',
#  'conservator',
#  'unfailing',
#  'courteous',
#  'abstracted',
#  'invalidates',
#  'fumbling',
#  'orders',
#  'patented',
#  'drunkard',
#  'drownings',
#  'drawbridge',
#  'commonalities',
#  'aberration',
#  'galled',
#  'curmudgeons',
#  'bossier',
#  'pasturing',
#  'toying',
#  'voters',
#  'moralities',
#  'ticketed',
#  'recollected',
#  'prospective',
#  'appreciating',
#  'unfavourable',
#  'swads',
#  'soundproof',
#  'laudatory',
#  'lesser',
#  'protesting',
#  'advocated',
#  'stopover',
#  'gangland',
#  'fawned',
#  'vaguely',
#  'conducts',
#  'lima',
#  'automates',
#  'monetary',
#  'pitchdark',
#  'unoccupied',
#  'sufferer',
#  'plus',
#  'insults',
#  'garottes',
#  'earphones',
#  'beautician',
#  'echoing',
#  'palely',
#  'gnarled',
#  'boardings',
#  'singed',
#  'niftily',
#  'cowriter',
#  'guttersnipe',
#  'rice',
#  'thickset',
#  'pacemakers',
#  'floe',
#  'troy',
#  'demists',
#  'hones',
#  'beloved',
#  'argument',
#  'stalked',
#  'cheapish',
#  'contented',
#  'nipped',
#  'multiplies',
#  'shaves',
#  'silo',
#  'users',
#  'picked',
#  'amalgamations',
#  'civilly',
#  'prompts',
#  'gander',
#  'hinderer',
#  'normals',
#  'inertness',
#  'depositories',
#  'indispensability',
#  'constrains',
#  'watchdog',
#  'stewardesses',
#  'tabling',
#  'suture',
#  'endorsement',
#  'injected',
#  'undertakers',
#  'suction',
#  'sounded',
#  'boneless',
#  'poodle',
#  'tapered',
#  'tensor',
#  'codicils',
#  'throat',
#  'souvenir',
#  'militate',
#  'testing',
#  'avariciousness',
#  'cakes',
#  'curfews',
#  'purgatorial',
#  'facility',
#  'bum',
#  'quelled',
#  'resilience',
#  'repayment',
#  'stigmatised',
#  'unsafely',
#  'pederasts',
#  'bemoaning',
#  'teleprinter',
#  'babbles',
#  'promises',
#  'unsurfaced',
#  'fireball',
#  'eclairs',
#  'temptations',
#  'rethought',
#  'magic',
#  'lectureships',
#  'symbolically',
#  'science',
#  'interjected',
#  'yawl',
#  'devoid',
#  'extradition',
#  'plumed',
#  'burden',
#  'objects',
#  'affably',
#  'firstborn',
#  'improvements',
#  'reconsult',
#  'disability',
#  'consultations',
#  'cantaloupe',
#  'rechecking',
#  'adopts',
#  'unvanquished',
#  'piazzas',
#  'bats',
#  'bra',
#  'sprouted',
#  'weepy',
#  'bombast',
#  'longlost',
#  'complexity',
#  'stunner',
#  'topple',
#  'poison',
#  'mishearing',
#  'pampering',
#  'inauthenticity',
#  'paprika',
#  'aliening',
#  'snags',
#  'abetting',
#  'rad',
#  'outgrowths',
#  'beckon',
#  'meatier',
#  'symbolise',
#  'bleeper',
#  'hatful',
#  'miserly',
#  'paroxysm',
#  'immortally',
#  'chandeliers',
#  'bleached',
#  'theft',
#  'handiwork',
#  'keypad',
#  'suzerainty',
#  'reclothe',
#  'hellfire',
#  'gamesmen',
#  'bronchi',
#  'disintegrates',
#  'shortlived',
#  'substantiate',
#  'illmannered',
#  'fraternise',
#  'slips',
#  'chafes',
#  'requiring',
#  'brickbats',
#  'paramagnetic',
#  'mysterious',
#  'mill',
#  'torturer',
#  'miscarry',
#  'mutable',
#  'unseaworthiness',
#  'prospectuses',
#  'stack',
#  'masterwork',
#  'champion',
#  'quarrying',
#  'engulf',
#  'dishcloth',
#  'tulip',
#  'gullies',
#  'shred',
#  'diffracting',
#  'ameliorating',
#  'verbs',
#  'unpolluted',
#  'martins',
#  'themas',
#  'wheatgerm',
#  'stained',
#  'sparse',
#  'characterised',
#  'spewed',
#  'creditworthiness',
#  'bowel',
#  'ferrets',
#  'lightheartedly',
#  'foothill',
#  'tamest',
#  'quarrel',
#  'roasts',
#  'hygienist',
#  'pimpernel',
#  'forbids',
#  'unlearned',
#  'scrolling',
#  'sketchbooks',
#  'elliptically',
#  'buckling',
#  'verb',
#  'vesicles',
#  'truncate',
#  'gazetteer',
#  'imaginable',
#  'accreted',
#  'eta',
#  'counteracting',
#  'dahlias',
#  'sifted',
#  'arbitrageur',
#  'barked',
#  'concepts',
#  'muds',
#  'lapful',
#  'unequalled',
#  'churchyard',
#  'foreskins',
#  'elects',
#  'griped',
#  'turnaround',
#  'buttonholed',
#  'aurevoir',
#  'forfeited',
#  'curbed',
#  'spays',
#  'sweetbread',
#  'squaring',
#  'trapping',
#  'exacts',
#  'auditioning',
#  'recode',
#  'fluttery',
#  'stripiest',
#  'handover',
#  'ionised',
#  'rollicking',
#  'moduli',
#  'appendage',
#  'arrowheads',
#  'immovability',
#  'destroyable',
#  'illogical',
#  'singe',
#  'survivals',
#  'undisguised',
#  'likened',
#  'turnstile',
#  'overwrote',
#  'demoted',
#  'umbrellas',
#  'bali',
#  'employed',
#  'freaks',
#  'hairpiece',
#  'selfconfidence',
#  'liquors',
#  'spot',
#  'phenols',
#  'couturier',
#  'buckshot',
#  'rephrasing',
#  'shamelessness',
#  'biotechnologist',
#  'fracture',
#  'dislike',
#  'sanding',
#  'jointing',
#  'disturbances',
#  'hides',
#  'rubicund',
#  'causation',
#  'pelvic',
#  'gouda',
#  'stuffiest',
#  'contraction',
#  'thane',
#  'overflown',
#  'airless',
#  'subroutine',
#  'potshot',
#  'derails',
#  'soprano',
#  'tamed',
#  'halfhourly',
#  'renegotiate',
#  'moaner',
#  'taxpayers',
#  'sailcloth',
#  'comptroller',
#  'busies',
#  'abject',
#  'unprejudiced',
#  'octaves',
#  'casanova',
#  'enslavement',
#  'tramped',
#  'tingles',
#  'arachnophobia',
#  'ricochet',
#  'buffing',
#  'conflation',
#  'haughtier',
#  'nitrates',
#  'fizzled',
#  'clause',
#  'immunity',
#  'unsuppressed',
#  'fruiting',
#  'cropper',
#  'pervasive',
#  'dribble',
#  'stalagmite',
#  'sequins',
#  'everlasting',
#  'known',
#  'undertaking',
#  'quintessentially',
#  'lighthouses',
#  'torpedoed',
#  'reproductions',
#  'monasteries',
#  'securest',
#  'moths',
#  'beaus',
#  'arrangement',
#  'unmolested',
#  'breathed',
#  'starkest',
#  'oxcart',
#  'variances',
#  'ave',
#  'scrabbling',
#  'oology',
#  'ideological',
#  'half',
#  'typography',
#  'smellier',
#  'retrieves',
#  'wrought',
#  'diplexers',
#  'vagabonds',
#  'incineration',
#  'hut',
#  'contingency',
#  'ball',
#  'reassuringly',
#  'professionally',
#  'leviathan',
#  'overhand',
#  'occurring',
#  'engineered',
#  'equilateral',
#  'neckband',
#  'skims',
#  'entrench',
#  'cannibalistic',
#  'oats',
#  'spheric',
#  'connotes',
#  'topmost',
#  'holster',
#  'trampled',
#  'coursebook',
#  'nudist',
#  'alleles',
#  'demonstrator',
#  'clans',
#  'aerials',
#  'flippancy',
#  'fieldworker',
#  'kneecaps',
#  'inconclusive',
#  'eyes',
#  'moped',
#  'rankings',
#  'taunts',
#  'impugning',
#  'summed',
#  'amaze',
#  'extract',
#  'epistemological',
#  'glassful',
#  'frank',
#  'operatives',
#  'miscarriage',
#  'shibboleths',
#  'struggled',
#  'outbound',
#  'supervisors',
#  'chirps',
#  'peak',
#  'congestion',
#  'fastens',
#  'unpaved',
#  'destitute',
#  'snail',
#  'watch',
#  'silicate',
#  'drowsiness',
#  'fractionating',
#  'humps',
#  'diadem',
#  'privatisation',
#  'stretching',
#  'agreeably',
#  'kinsfolk',
#  'apparelled',
#  'culminated',
#  'wearing',
#  'hue',
#  'splitting',
#  'cookware',
#  'columnists',
#  'knifed',
#  'brainstorms',
#  'dramatise',
#  'crawls',
#  'accuse',
#  'composure',
#  'prodigal',
#  'knickers',
#  'gigabytes',
#  'arced',
#  'pirating',
#  'sketchily',
#  'birdtables',
#  'furnishers',
#  'celebrations',
#  'perspex',
#  'sawyers',
#  'rotational',
#  'zambian',
#  'minders',
#  'arches',
#  'lutes',
#  'wearyingly',
#  'remorse',
#  'howitzer',
#  'risque',
#  'disregarded',
#  'cordite',
#  'throbbing',
#  'exclusively',
#  'incantations',
#  'mistreated',
#  'productions',
#  'cooped',
#  'sociologists',
#  'dreamier',
#  'dispirited',
#  'caters',
#  'limericks',
#  'inferred',
#  'tadpoles',
#  'underclothes',
#  'knave',
#  'fundamentalism',
#  'tardily',
#  'spanks',
#  'ohm',
#  'germinal',
#  'murderers',
#  'tigris',
#  'hieroglyphic',
#  'tooting',
#  'nurses',
#  'reddened',
#  'purport',
#  'crashers',
#  'domestics',
#  'stipulates',
#  'groom',
#  'bunk',
#  'gipsy',
#  'expounds',
#  'hoarding',
#  'decomposed',
#  'neatening',
#  'virtuosity',
#  'draws',
#  'sprites',
#  'baltic',
#  'testes',
#  'discern',
#  'sharpest',
#  'detain',
#  'libelling',
#  'impersonally',
#  'entry',
#  'dramatics',
#  'intimidating',
#  'yea',
#  'titling',
#  'pickerels',
#  'cationic',
#  'borer',
#  'mogul',
#  'swamplands',
#  'badtempered',
#  'undamaged',
#  'decryption',
#  'incitement',
#  'shears',
#  'painstaking',
#  'conspecific',
#  'noxiously',
#  'extortion',
#  'mythical',
#  'distilled',
#  'thermodynamically',
#  'teenagers',
#  'deliciously',
#  'founded',
#  'handwritten',
#  'numbered',
#  'turmoil',
#  'communique',
#  'indications',
#  'nooks',
#  'gridiron',
#  'mercilessly',
#  'anyhow',
#  'threatening',
#  'hayfield',
#  'privy',
#  'waterresistant',
#  'titillate',
#  'moorhen',
#  'chatterer',
#  'valve',
#  'goslings',
#  'inbuilt',
#  'severable',
#  'beseeches',
#  'paperwork',
#  'niches',
#  'outmanoeuvred',
#  'weedkiller',
#  'locating',
#  'inducing',
#  'innocents',
#  'coincided',
#  'travelogue',
#  'sedatives',
#  'smote',
#  'intelligent',
#  'buffoons',
#  'applecart',
#  'barge',
#  'aerodynamic',
#  'bleakly',
#  'professors',
#  'counterbalance',
#  'jewsharp',
#  'chequebooks',
#  'european',
#  'risen',
#  'presumable',
#  'havenots',
#  'setting',
#  'condenser',
#  'cuddle',
#  'bludgeoning',
#  'dispatching',
#  'religions',
#  'dweller',
#  'song',
#  'jussive',
#  'anything',
#  'arson',
#  'rigidities',
#  'tatty',
#  'popped',
#  'gallium',
#  'unmagnified',
#  'entailed',
#  'enchain',
#  'blunting',
#  'boring',
#  'skidded',
#  'clothe',
#  'sawn',
#  'injury',
#  'hypothesiser',
#  'bawled',
#  'antibiotic',
#  'farfetched',
#  'complexion',
#  'inflows',
#  'initially',
#  'snip',
#  'snarls',
#  'prosecutes',
#  'certifying',
#  'decimating',
#  'action',
#  'gruffly',
#  'piglet',
#  'antistatic',
#  'taunting',
#  'unappetising',
#  'showpieces',
#  'dereliction',
#  'ways',
#  'southbound',
#  'nosing',
#  'engels',
#  'capillaries',
#  'remarkably',
#  'to',
#  'elevators',
#  'dolerite',
#  'slitting',
#  'czars',
#  'fullbacks',
#  'balmy',
#  'unsharable',
#  'thoroughfares',
#  'disaffiliate',
#  'jealousy',
#  'braincell',
#  'eagerness',
#  'crescendo',
#  'duckbilled',
#  'victimised',
#  'optoelectronic',
#  'godlike',
#  'intensities',
#  'pops',
#  'railwaymen',
#  'separating',
#  'monks',
#  'seducing',
#  'broadcasts',
#  'alveolar',
#  'kindly',
#  'photos',
#  'perplexing',
#  'thrived',
#  'purely',
#  'victimless',
#  'golfer',
#  'scree',
#  'duchies',
#  'grandpas',
#  'pedant',
#  'wingspan',
#  'sealants',
#  'megawatt',
#  'immunodeficiency',
#  'wavily',
#  'multifunction',
#  'simultaneity',
#  'roguishly',
#  'tiered',
#  'flagons',
#  'oversimplifications',
#  'centroids',
#  'garbed',
#  'embodies',
#  'lookingglass',
#  'judgments',
#  'escarp',
#  'recalcitrant',
#  'conform',
#  'rosters',
#  'ricking',
#  'cadged',
#  'macroeconomics',
#  'despoiled',
#  'emigrants',
#  'fatter',
#  'dons',
#  'foremen',
#  'pealed',
#  'outbreak',
#  'misspelling',
#  'fulfilled',
#  'gangrenous',
#  'redundantly',
#  'sextuplets',
#  'archive',
#  'convertibility',
#  'nestable',
#  'averse',
#  'freshmen',
#  'political',
#  'guardhouse',
#  'tricksters',
#  'pions',
#  'silencer',
#  'latitudinal',
#  'attainment',
#  'scribe',
#  'contaminant',
#  'synopsis',
#  'discrepancy',
#  'conjuring',
#  'statehood',
#  'crusted',
#  'thefts',
#  'deviousness',
#  'extinguishes',
#  'edison',
#  'unfolding',
#  'immorality',
#  'prevalence',
#  'hijacked',
#  'draughtsman',
#  'overhead',
#  'positively',
#  'dotting',
#  'crookedness',
#  'tours',
#  'shifts',
#  'gatherer',
#  'truants',
#  'inorganic',
#  'easternmost',
#  'punchcard',
#  'pimply',
#  'exogenous',
#  'flamboyantly',
#  'beefs',
#  'pseudo',
#  'stiffener',
#  'ruptured',
#  'erect',
#  'turntables',
#  'stalk',
#  'kickstart',
#  'eucalyptus',
#  'diaphragms',
#  'enraging',
#  'molestation',
#  'empire',
#  'ramble',
#  'briny',
#  'egocentric',
#  'chanteuse',
#  'dehorn',
#  'trigram',
#  'armpit',
#  'stifles',
#  'indiscreetly',
#  'motherhood',
#  'platypuses',
#  'wardrobe',
#  'vocabularies',
#  'harshness',
#  'idolaters',
#  'lodgings',
#  'embracing',
#  'scalability',
#  'paling',
#  'walking',
#  'begone',
#  'courthouse',
#  'buddings',
#  'waterline',
#  'soilings',
#  'clinches',
#  'porridge',
#  'boomeranging',
#  'nebulously',
#  'emerges',
#  'conception',
#  'leanings',
#  'tendered',
#  'disseminate',
#  'unreached',
#  'unpersuaded',
#  'afforestation',
#  'serial',
#  'smallholdings',
#  'unfilled',
#  'untutored',
#  'onslaughts',
#  'catchphrase',
#  'vitrified',
#  'kitting',
#  'pontiff',
#  'mesolithic',
#  'warhorses',
#  'abbreviating',
#  'dieselelectric',
#  'unanswerable',
#  'gipsies',
#  'scantier',
#  'signing',
#  'sanctifying',
#  'colliding',
#  'underline',
#  'considerations',
#  'abbreviates',
#  'hirsuteness',
#  'chekov',
#  'respecify',
#  'premiere',
#  'bathhouse',
#  'chieftains',
#  'visionary',
#  'hydrofoils',
#  'wrestling',
#  'wielding',
#  'sups',
#  'highs',
#  'enough',
#  'antlion',
#  'muses',
#  'intrigue',
#  'unsuspecting',
#  'viva',
#  'mudflow',
#  'cheating',
#  'diapers',
#  'partnerships',
#  'summa',
#  'peeper',
#  'summoned',
#  'underdog',
#  'islet',
#  'overpoweringly',
#  'thirst',
#  'ballyhoo',
#  'ethane',
#  'clip',
#  'internment',
#  'womanliness',
#  'devastating',
#  'partly',
#  'festered',
#  'syntactically',
#  'tongueincheek',
#  'autopsies',
#  'expunges',
#  'slander',
#  'parasol',
#  'privatisations',
#  'superb',
#  'alive',
#  'peals',
#  'accelerometer',
#  'bloodcurdling',
#  'headmaster',
#  'robbery',
#  'involve',
#  'nullified',
#  'rushing',
#  'altercate',
#  'boxed',
#  'decade',
#  'creamery',
#  'chipmunk',
#  'prunes',
#  'miscue',
#  'turban',
#  'cannon',
#  'adverse',
#  'perjured',
#  'envying',
#  'centurion',
#  'fatigues',
#  'efficient',
#  'slate',
#  'amino',
#  'childbirth',
#  'connecting',
#  'landslip',
#  'prefigured',
#  'occupant',
#  ...]

# %% [markdown]
# Now the tricky part. Create a dictionary with 26 keys, each key being a letter of the alphabet. And, the value associated with each key is a list of all the words in the big word list that begin with that letter. Output it to verify.
#
# *Hint- you may not be able to do this efficiently in a single step.*

# %%
dict = {
    'a':[i for i in words if i.startswith('a')]
#     'b':[x for x in words if x.startswith('b')]
#     'c':[l for l in words if l.startswith('c')]
#     'd':[i for i in words if i.startswith('d')]
#     'e':[i for i in words if i.startswith('e')]
}
print(dict)

# hi mr. gorton, i got this off a website and it only works for one letter but if i try to take b out of a comment, it stops working. 
#do i need to make 26 seperate dictionaries? i'm pretty sure this is the way they did on the website

#credit: info on how to make list to dictionary from https://careerkarma.com/blog/python-convert-list-to-dictionary/
#credit: info on how to find all words in list that start with letter https://stackoverflow.com/questions/53915964/how-to-find-words-in-a-list-that-starts-with-a-certain-letter-the-user-asked-for
# Out:
# {'a': ['assimilated', 'anodyne', 'alights', 'acuter', 'amplified', 'abstracted', 'aberration', 'appreciating', 'advocated', 'automates', 'argument', 'amalgamations', 'avariciousness', 'affably', 'adopts', 'aliening', 'abetting', 'ameliorating', 'accreted', 'arbitrageur', 'aurevoir', 'auditioning', 'appendage', 'arrowheads', 'airless', 'abject', 'arachnophobia', 'arrangement', 'ave', 'alleles', 'aerials', 'amaze', 'agreeably', 'apparelled', 'accuse', 'arced', 'arches', 'anyhow', 'applecart', 'aerodynamic', 'anything', 'arson', 'antibiotic', 'action', 'antistatic', 'alveolar', 'archive', 'averse', 'attainment', 'armpit', 'afforestation', 'abbreviating', 'abbreviates', 'antlion', 'autopsies', 'alive', 'accelerometer', 'altercate', 'adverse', 'amino', 'aorist', 'alphabet', 'admiration', 'assaulted', 'altarpieces', 'anagrammatic', 'auditing', 'anguish', 'adumbrated', 'adjusted', 'articulatory', 'avowing', 'antithetic', 'anomalies', 'aura', 'antidotes', 'angler', 'antibiotics', 'amazon', 'audited', 'ambivalence', 'avenues', 'appeasement', 'altering', 'anhydrous', 'anteaters', 'ambition', 'autocrats', 'adjudication', 'astute', 'abut', 'algal', 'apothecaries', 'ambling', 'avuncular', 'agitates', 'agriculture', 'annotations', 'angioplasty', 'air', 'accesses', 'amused', 'airiness', 'accompanies', 'audition', 'assignees', 'adjudges', 'assertiveness', 'annually', 'aardvark', 'astraddle', 'ascetic', 'airframes', 'agent', 'abloom', 'algebraist', 'accosting', 'anglers', 'amateurism', 'anaphoric', 'akimbo', 'actuality', 'abolition', 'alleges', 'addicted', 'avoirdupois', 'asian', 'aftercare', 'amber', 'associates', 'asphyxia', 'applauded', 'agoraphobic', 'anisotropy', 'acumen', 'applicability', 'aphelion', 'admittances', 'anthropologists', 'appraising', 'anteroom', 'analysed', 'amongst', 'animist', 'alliterate', 'acuity', 'anginal', 'aversion', 'alienate', 'allotments', 'affection', 'annotated', 'assegais', 'admirers', 'arguable', 'achy', 'attenders', 'atoll', 'assembles', 'awhile', 'absurdly', 'authorisations', 'avulsion', 'affirming', 'adventurous', 'autobiographies', 'affirmations', 'airily', 'affective', 'asynchronously', 'anniversary', 'anarchy', 'accumulators', 'accentuates', 'arena', 'agitating', 'artistically', 'asymptotic', 'apartness', 'applauding', 'arabians', 'acrobat', 'appease', 'acknowledge', 'arabia', 'armfuls', 'aristocratic', 'adulterous', 'admirable', 'aerobatics', 'abusively', 'arbitrageurs', 'acetal', 'announced', 'annihilate', 'arrears', 'autarchy', 'archived', 'antidote', 'academia', 'achingly', 'attentions', 'antenatal', 'alanine', 'architectural', 'allegiance', 'amphibia', 'affiliating', 'arteries', 'acidity', 'adamant', 'additively', 'appending', 'appendix', 'apprehend', 'airtight', 'anthropology', 'amounted', 'aiding', 'authenticity', 'alienation', 'accountancy', 'abstractly', 'amnesiac', 'ambiance', 'azores', 'analogues', 'avalanches', 'acorns', 'appropriates', 'antagonising', 'antedate', 'armada', 'apron', 'aids', 'assessors', 'amputation', 'abomination', 'abnormally', 'apes', 'ambivalent', 'appetites', 'accompanied', 'algorithmic', 'acids', 'appreciable', 'awkwardest', 'appealed', 'alluring', 'astray', 'alcoholics', 'archipelago', 'artists', 'appreciative', 'antiquities', 'alluvia', 'aboard', 'actuator', 'around', 'ape', 'advertise', 'authorising', 'analyses', 'acts', 'accessing', 'allotting', 'agonisingly', 'archetypal', 'absolutist', 'aggregation', 'animated', 'amputee', 'aspires', 'archaisms', 'amending', 'amusement', 'assented', 'attributes', 'aloof', 'amphibian', 'anemia', 'attachment', 'anticipate', 'appeaser', 'amulet', 'abnegation', 'accountants', 'artfully', 'assures', 'avoids', 'arachnids', 'appertain', 'abdicate', 'antigenic', 'awfully', 'almshouse', 'anoint', 'advantages', 'alumni', 'answer', 'anatomist', 'anywhere', 'attract', 'airships', 'aardwolf', 'aerosol', 'acclimatising', 'arthropod', 'axiomatically', 'abscissas', 'aspiration', 'aright', 'affording', 'assumptions', 'adventurer', 'alas', 'admiral ...

# %% [markdown]
# Use your dictionary to create a new dictionary that has each letter of the alphabet and the number of words that start with that letter.

# %% [markdown]
# What is the most common first letter in your list of words? (You can just look at your dictionary to answer this.)
#
# ## Collection Counters 🌶️🌶️🌶️ (aka Ridiculous)
#
# See: https://stackoverflow.com/questions/613183/how-do-i-sort-a-dictionary-by-value
#
# What if you'd like to know the most common first letter of words in our list? You could try to somehow sort the dictionary from above.
#
# Or...

# %% [markdown]
# And of course, I want to know the most common first two letters in my word list, and do it in one line of code!

# %% [markdown]
# How many combinations are there?
